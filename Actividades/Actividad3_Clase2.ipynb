# %% [markdown]
# ## Actividad: Clases geométricas en Python
#
# En esta actividad, vamos a definir dos clases en Python, "Cuadrado" y "Rectangulo", la clase "Cuadrado" heredará de la clase "Rectangulo". La clase "Rectangulo" tendrá dos atributos, "ancho" y "alto", que representan las dimensiones del rectángulo. La clase "Cuadrado" tendrá un atributo "lado" que representa la longitud del lado del cuadrado. En la clase "Cuadrado", se sobrescribirá el método ```__init__``` para inicializar el atributo "lado", y se asegurará que "ancho" y "alto" sean iguales. Y se implementará el método ```__str__``` para imprimir los atributos del cuadrado.

# %%
#Creamos la clase rectangulo

class Rectangulo:
    def __init__(self,ancho,alto):
        self.ancho=ancho
        self.alto=alto
        
    def calcular_area(self):
        return self.ancho*self.alto
    
    def calcular_perimetro(self):
        return 2*(self.ancho+self.alto)
    
    def __str__(self):
        return f"Rectangulo de ancho {self.ancho} y alto {self.alto}"


#Creamos la subclase cuadrado que hereda de rectangulo

class Cuadrado(Rectangulo):
    def __init__(self,lado):
        #super() se utiliza para llamar al constructor de la clase principal "Rectangulo" y pasarle el valor del lado como ancho y alto
        super().__init__(lado,lado)
        self.lado=lado
        
    def __str__(self):
        return f"Cuadrado de lado {self.lado}"

#Creamos un objeto de la clase rectangulo y otro de la clase cuadrado
rectangulo1=Rectangulo(4,5)
cuadrado1=Cuadrado(4)


#Imprimimos el area y el perimetro de ambos objetos
print(f"El area del {rectangulo1} es: {rectangulo1.calcular_area()}")
print(f"El perimetro del {rectangulo1} es: {rectangulo1.calcular_perimetro()}")
print(f"El area del {cuadrado1} es: {cuadrado1.calcular_area()}")
print(f"El perimetro del {cuadrado1} es: {cuadrado1.calcular_perimetro()}")
# Out:
# El area del Rectangulo de ancho 4 y alto 5 es: 20
# El perimetro del Rectangulo de ancho 4 y alto 5 es: 18
# El area del Cuadrado de lado 4 es: 16
# El perimetro del Cuadrado de lado 4 es: 16
